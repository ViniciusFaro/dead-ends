# %% [markdown]
# # Dead Ends of Carbonate rocks study with python and pytorch for deep learning
#
# ### importing matlab imagens into python with scipy

# %%
# imports
from scipy.io import loadmat
from scipy.io import loadmat
import numpy as np
import matplotlib.pyplot as plt

# %%
x = loadmat(r'C:\Users\USER\Desktop\jupytervscode\LabMems\dead-ends\data\ImCrop.mat')

# Display variable names
print(x.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Acrop', 'B1crop', 'B2crop', 'B3crop', 'B4crop'])

# %%
img = x['Acrop'][0][1][0]
plt.imshow(img)
plt.title("First image")
plt.axis('off')
plt.show()

# %%
y = loadmat(r'C:\Users\USER\Desktop\jupytervscode\LabMems\dead-ends\data\DeadEnd.mat')

# Display variable names
print(y.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Anew', 'Nfig'])

# %%
img = y['Anew'][0][3][0]
plt.imshow(img)
plt.title("First image")
plt.axis('off')
plt.show()

# %% [markdown]
# #### we'll be working with `Acrop` (input) and `Anew` (label)
